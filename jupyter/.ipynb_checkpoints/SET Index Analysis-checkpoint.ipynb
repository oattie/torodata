# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../toroapp/static/data/set.csv", index_col="Date", parse_dates=True)

# %%
df['Adj Close']["2017":"2018"].plot(title="SET Index - www.toro.in.th", figsize=(20, 7))

# %%
ohlc_dict = {'Open':'first','High':'max','Low':'min','Close': 'last','Volume': 'sum','Adj Close': 'last'}
df_m = df.resample('M', how=ohlc_dict)
# Out:
# /home/quant/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %%
# Monthly return
m_return = df_m.pct_change(1)*100
m_return.tail(12)
# Out:
#                 Open      High       Low     Close     Volume  Adj Close
# Date
# 2018-02-28  4.200931  0.240251  0.013651  0.178996  -8.392978   0.178996
# 2018-03-31 -0.674110 -1.451004 -0.249103 -2.943507   7.611331  -2.943507
# 2018-04-30 -2.550558 -1.087296 -1.656280  0.216748 -16.065376   0.216748
# 2018-05-31  0.143685 -0.455205 -0.762372 -2.985209  41.071781  -2.985209
# 2018-06-30 -2.836935 -2.840517 -7.422315 -7.608123 -10.529785  -7.608123
# 2018-07-31 -7.518893 -2.113942  0.104753  6.656514   3.814312   6.656514
# 2018-08-31  6.792068  1.232466  4.952280  1.162893   0.556203   1.162893
# 2018-09-30  0.965124  2.078410  0.070274  2.023142   3.060201   2.023142
# 2018-10-31  2.343868 -0.088304 -4.181697 -4.971504   1.407722  -4.971504
# 2018-11-30 -5.116042 -4.314867  0.135931 -1.635023  -9.156884  -1.635023
# 2018-12-31 -0.597438 -0.645983 -3.249779 -4.746010 -19.140158  -4.746010
# 2019-01-31 -5.719099 -5.948784  0.232766  0.719365 -83.329955   0.719365

# %%
m_return['Adj Close']["2017":"2019"].plot(title="SET Index - www.toro.in.th", figsize=(20, 7))

# %%
# Select only Jan of every year
m_return['2017-01':'2018-01']
# Out:
#                 Open      High       Low     Close     Volume  Adj Close
# Date
# 2017-01-31  1.897135  3.505153  3.202386  2.227566  23.422199   2.227566
# 2017-02-28  1.720386 -0.311096  0.579350 -1.125334  -7.600464  -1.125334
# 2017-03-31 -0.804378 -0.679906 -1.719039  0.997076   5.636280   0.997076
# 2017-04-30  1.025306  0.286443  1.613051 -0.558056 -33.515236  -0.558056
# 2017-05-31 -0.753256 -0.947468 -1.400762 -0.297513  25.860718  -0.297513
# 2017-06-30 -0.287886  1.057519  1.816959  0.837570   8.652500   0.837570
# 2017-07-31  0.966660 -0.312364  0.291117  0.085093 -24.721967   0.085093
# 2017-08-31 -0.206698  2.528182 -0.500623  2.543018  24.002792   2.543018
# 2017-09-30  3.016672  3.198214  3.732120  3.526879  24.551416   3.526879
# 2017-10-31  3.442704  3.072880  3.636870  2.881374  12.099803   2.881374
# 2017-11-30  3.075327 -0.009250  0.449489 -1.393076  -8.983695  -1.393076
# 2017-12-31 -1.422952  1.949539  0.326683  3.318035 -27.576358   3.318035
# ...
